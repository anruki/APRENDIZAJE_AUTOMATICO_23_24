# %% [markdown]
# <a href="https://colab.research.google.com/github/anruki/APRENDIZAJE_AUTOMATICO_23_24/blob/main/LAB01_Ana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Descarga de vacunaciones.csv

# %%
import requests
import pandas as pd

# URL del archivo CSV en GitHub
url = "https://raw.githubusercontent.com/CeliaDiazSanchez/Data-Mining/LAB01/vacunaciones.csv"

# Realizar la solicitud GET para obtener el contenido del archivo
response = requests.get(url)

# Verificar si la solicitud fue exitosa (código de estado 200)
if response.status_code == 200:
    # Guardar el contenido del archivo en un archivo local
    with open('vacunaciones.csv', 'wb') as f:
        f.write(response.content)
    print("Archivo descargado exitosamente.")
else:
    print("Error al descargar el archivo.")

# Cargar el archivo CSV en un DataFrame de pandas
ds = pd.read_csv('vacunaciones.csv')

ds.head(3)
# Out:
# Archivo descargado exitosamente.
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  2021-01-10                 0.0                0.0
# 1  Albania      ALB  2021-01-11                 NaN                NaN
# 2  Albania      ALB  2021-01-12               128.0              128.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                64.0
# 2                      NaN                     NaN                64.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             0.0                            0.0
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            22.0
# 2                                  NaN                            22.0
#
#           vaccines         source_name  \
# 0  Pfizer/BioNTech  Ministry of Health
# 1  Pfizer/BioNTech  Ministry of Health
# 2  Pfizer/BioNTech  Ministry of Health
#
#                                       source_website
# 0  https://shendetesia.gov.al/vaksinimi-anticovid...
# 1  https://shendetesia.gov.al/vaksinimi-anticovid...
# 2  https://shendetesia.gov.al/vaksinimi-anticovid...

# %% [markdown]
# Veamos de qué tipo es cada columna del DataFrame

# %%
print(ds.dtypes)
# Out:
# country                                 object
# iso_code                                object
# date                                    object
# total_vaccinations                     float64
# people_vaccinated                      float64
# people_fully_vaccinated                float64
# daily_vaccinations_raw                 float64
# daily_vaccinations                     float64
# total_vaccinations_per_hundred         float64
# people_vaccinated_per_hundred          float64
# people_fully_vaccinated_per_hundred    float64
# daily_vaccinations_per_million         float64
# vaccines                                object
# source_name                             object
# source_website                          object
# dtype: object

# %% [markdown]
# Ordenamos las filas por su fecha para que estén en orden cronológico.

# %%
# Convertir la columna de fecha a formato datetime
ds['date'] = pd.to_datetime(ds['date'])

# Ordenar los datos por fecha
ds = ds.sort_values(by='date')

# %% [markdown]
# Y ahora ordenamos por país

# %%
# Ordenar las filas por país y fecha
ds = ds.sort_values(by=['country', 'date'])

ds.head(30)
# Out:
#     country iso_code       date  total_vaccinations  people_vaccinated  \
# 0   Albania      ALB 2021-01-10                 0.0                0.0
# 1   Albania      ALB 2021-01-11                 NaN                NaN
# 2   Albania      ALB 2021-01-12               128.0              128.0
# 3   Albania      ALB 2021-01-13               188.0              188.0
# 4   Albania      ALB 2021-01-14               266.0              266.0
# 5   Albania      ALB 2021-01-15               308.0              308.0
# 6   Albania      ALB 2021-01-16               369.0              369.0
# 7   Albania      ALB 2021-01-17               405.0              405.0
# 8   Albania      ALB 2021-01-18               447.0              447.0
# 9   Albania      ALB 2021-01-19               483.0              483.0
# 10  Albania      ALB 2021-01-20               519.0              519.0
# 11  Albania      ALB 2021-01-21               549.0              549.0
# 12  Albania      ALB 2021-01-22                 NaN                NaN
# 13  Albania      ALB 2021-01-23                 NaN                NaN
# 14  Albania      ALB 2021-01-24                 NaN                NaN
# 15  Albania      ALB 2021-01-25                 NaN                NaN
# 16  Albania      ALB 2021-01-26                 NaN                NaN
# 17  Albania      ALB 2021-01-27                 NaN                NaN
# 18  Albania      ALB 2021-01-28                 NaN                NaN
# 19  Albania      ALB 2021-01-29                 NaN                NaN
# 20  Albania      ALB 2021-01-30                 NaN                NaN
# 21  Albania      ALB 2021-01-31                 NaN                NaN
# 22  Albania      ALB 2021-02-01                 NaN                NaN
# 23  Albania      ALB 2021-02-02               550.0              549.0
# 24  Albania      ALB 2021-02-03                 NaN                NaN
# 25  Albania      ALB 2021-02-04                 NaN                NaN
# 26  Albania      ALB 2021-02-05                 NaN                NaN
# 27  Albania      ALB 2021-02-06                 NaN                NaN
# 28  Albania      ALB 2021-02-07                 NaN                NaN
# 29  Albania      ALB 2021-02-08                 NaN                NaN
#
#     people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                64.0
# 2                       NaN                     NaN                64.0
# 3                       NaN                    60.0                63.0
# 4                       NaN                    78.0                66.0
# 5                       NaN                    42.0                62.0
# 6                       NaN                    61.0                62.0
# 7                       NaN                    36.0                58.0
# 8                       NaN                    42.0                55.0
# 9                       NaN                    36.0                51.0
# 10                      NaN                    36.0                47.0
# 11                      NaN                    30.0                40.0
# 12                      NaN                     NaN                34.0
# 13                      NaN                     NaN                26.0
# 14                      NaN                     NaN                21.0
# 15                      NaN                     NaN                15.0
# 16                      NaN                     NaN                 9.0
# 17                      NaN                     NaN                 4.0
# 18                      NaN                     NaN                 NaN
# 19                      NaN                     NaN                 NaN
# 20                      NaN                     NaN                 NaN
# 21                      NaN                     NaN                 NaN
# 22                      NaN                     NaN                 NaN
# 23                      1.0                     NaN                 NaN
# 24                      NaN                     NaN                12.0
# 25                      NaN                     NaN                24.0
# 26                      NaN                     NaN                35.0
# 27                      NaN                     NaN                47.0
# 28                      NaN                     NaN                59.0
# 29                      NaN                     NaN                71.0
#
#     total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.00                           0.00
# 1                              NaN                            NaN
# 2                             0.00                           0.00
# 3                             0.01                           0.01
# 4                             0.01                           0.01
# 5                             0.01                           0.01
# 6                             0.01                           0.01
# 7                             0.01                           0.01
# 8                             0.02                           0.02
# 9                             0.02                           0.02
# 10                            0.02                           0.02
# 11                            0.02                           0.02
# 12                             NaN                            NaN
# 13                             NaN                            NaN
# 14                             NaN                            NaN
# 15                             NaN                            NaN
# 16                             NaN                            NaN
# 17                             NaN                            NaN
# 18                             NaN                            NaN
# 19                             NaN                            NaN
# 20                             NaN                            NaN
# 21                             NaN                            NaN
# 22                             NaN                            NaN
# 23                            0.02                           0.02
# 24                             NaN                            NaN
# 25                             NaN                            NaN
# 26                             NaN                            NaN
# 27                             NaN                            NaN
# 28                             NaN                            NaN
# 29                             NaN                            NaN
#
#     people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                   NaN                             NaN
# 1                                   NaN                            22.0
# 2                                   NaN                            22.0
# 3                                   NaN                            22.0
# 4                                   NaN                            23.0
# 5                                   NaN                            22.0
# 6                                   NaN                            22.0
# 7                                   NaN                            20.0
# 8                                   NaN                            19.0
# 9                                   NaN                            18.0
# 10                                  NaN                            16.0
# 11                                  NaN                            14.0
# 12                                  NaN                            12.0
# 13                                  NaN                             9.0
# 14                                  NaN                             7.0
# 15                                  NaN                             5.0
# 16                                  NaN                             3.0
# 17                                  NaN                             1.0
# 18                                  NaN                             NaN
# 19                                  NaN                             NaN
# 20                                  NaN                             NaN
# 21                                  NaN                             NaN
# 22                                  NaN                             NaN
# 23                                  0.0                             NaN
# 24                                  NaN                             4.0
# 25                                  NaN                             8.0
# 26                                  NaN                            12.0
# 27                                  NaN                            16.0
# 28                                  NaN                            21.0
# 29                                  NaN                            25.0
#
#            vaccines         source_name  \
# 0   Pfizer/BioNTech  Ministry of Health
# 1   Pfizer/BioNTech  Ministry of Health
# 2   Pfizer/BioNTech  Ministry of Health
# 3   Pfizer/BioNTech  Ministry of Health
# 4   Pfizer/BioNTech  Ministry of Health
# 5   Pfizer/BioNTech  Ministry of Health
# 6   Pfizer/BioNTech  Ministry of Health
# 7   Pfizer/BioNTech  Ministry of Health
# 8   Pfizer/BioNTech  Ministry of Health
# 9   Pfizer/BioNTech  Ministry of Health
# 10  Pfizer/BioNTech  Ministry of Health
# 11  Pfizer/BioNTech  Ministry of Health
# 12  Pfizer/BioNTech  Ministry of Health
# 13  Pfizer/BioNTech  Ministry of Health
# 14  Pfizer/BioNTech  Ministry of Health
# 15  Pfizer/BioNTech  Ministry of Health
# 16  Pfizer/BioNTech  Ministry of Health
# 17  Pfizer/BioNTech  Ministry of Health
# 18  Pfizer/BioNTech  Ministry of Health
# 19  Pfizer/BioNTech  Ministry of Health
# 20  Pfizer/BioNTech  Ministry of Health
# 21  Pfizer/BioNTech  Ministry of Health
# 22  Pfizer/BioNTech  Ministry of Health
# 23  Pfizer/BioNTech  Ministry of Health
# 24  Pfizer/BioNTech  Ministry of Health
# 25  Pfizer/BioNTech  Ministry of Health
# 26  Pfizer/BioNTech  Ministry of Health
# 27  Pfizer/BioNTech  Ministry of Health
# 28  Pfizer/BioNTech  Ministry of Health
# 29  Pfizer/BioNTech  Ministry of Health
#
#                                        source_website
# 0   https://shendetesia.gov.al/vaksinimi-anticovid...
# 1   https://shendetesia.gov.al/vaksinimi-anticovid...
# 2   https://shendetesia.gov.al/vaksinimi-anticovid...
# 3   https://shendetesia.gov.al/vaksinimi-anticovid...
# 4   https://shendetesia.gov.al/vaksinimi-anticovid...
# 5   https://shendetesia.gov.al/vaksinimi-anticovid...
# 6   https://shendetesia.gov.al/vaksinimi-anticovid...
# 7   https://shendetesia.gov.al/vaksinimi-anticovid...
# 8   https://shendetesia.gov.al/vaksinimi-anticovid...
# 9   https://shendetesia.gov.al/vaksinimi-anticovid...
# 10  https://shendetesia.gov.al/vaksinimi-anticovid...
# 11  https://shendetesia.gov.al/vaksinimi-anticovid...
# 12  https://shendetesia.gov.al/vaksinimi-anticovid...
# 13  https://shendetesia.gov.al/vaksinimi-anticovid...
# 14  https://shendetesia.gov.al/vaksinimi-anticovid...
# 15  https://shendetesia.gov.al/vaksinimi-anticovid...
# 16  https://shendetesia.gov.al/vaksinimi-anticovid...
# 17  https://shendetesia.gov.al/vaksinimi-anticovid...
# 18  https://shendetesia.gov.al/vaksinimi-anticovid...
# 19  https://shendetesia.gov.al/vaksinimi-anticovid...
# 20  https://shendetesia.gov.al/vaksinimi-anticovid...
# 21  https://shendetesia.gov.al/vaksinimi-anticovid...
# 22  https://shendetesia.gov.al/vaksinimi-anticovid...
# 23  https://shendetesia.gov.al/vaksinimi-anticovid...
# 24  https://shendetesia.gov.al/vaksinimi-anticovid...
# 25  https://shendetesia.gov.al/vaksinimi-anticovid...
# 26  https://shendetesia.gov.al/vaksinimi-anticovid...
# 27  https://shendetesia.gov.al/vaksinimi-anticovid...
# 28  https://shendetesia.gov.al/vaksinimi-anticovid...
# 29  https://shendetesia.gov.al/vaksinimi-anticovid...

# %% [markdown]
# # 1.
# Lo primero será evitar los “missing values” de la columna “people vaccinated”. Para ello
# cogeremos los valores de los 3 días anteriores (si existen, en caso contrario dos o uno) y su media para
# rellenar dicha celda.

# %% [markdown]
# Como las filas ya están ordenadas por país y fecha, simplemente hay que tomar la media de las 3 entradas anteriores a un NaN

# %%
# creo una copia de ds para modificarla sin afectar al original
df = ds.copy()
id(df), id(ds)
# Out:
# (139748163583616, 139748163580784)

# %%
# Iterar sobre los NaN y calcular la media de los tres valores anteriores
for i in range(len(df)):
    if pd.isna(df.at[i, 'people_vaccinated']):
        start_index = max(0, i - 3)  # Índice de inicio para calcular la media
        end_index = i  # Índice final para calcular la media
        mean_value = df.iloc[start_index:end_index]['people_vaccinated'].mean()
        df.at[i, 'people_vaccinated'] = mean_value

# %%
df.head(30)
# Out:
#     country iso_code       date  total_vaccinations  people_vaccinated  \
# 0   Albania      ALB 2021-01-10                 0.0           0.000000
# 1   Albania      ALB 2021-01-11                 NaN           0.000000
# 2   Albania      ALB 2021-01-12               128.0         128.000000
# 3   Albania      ALB 2021-01-13               188.0         188.000000
# 4   Albania      ALB 2021-01-14               266.0         266.000000
# 5   Albania      ALB 2021-01-15               308.0         308.000000
# 6   Albania      ALB 2021-01-16               369.0         369.000000
# 7   Albania      ALB 2021-01-17               405.0         405.000000
# 8   Albania      ALB 2021-01-18               447.0         447.000000
# 9   Albania      ALB 2021-01-19               483.0         483.000000
# 10  Albania      ALB 2021-01-20               519.0         519.000000
# 11  Albania      ALB 2021-01-21               549.0         549.000000
# 12  Albania      ALB 2021-01-22                 NaN         517.000000
# 13  Albania      ALB 2021-01-23                 NaN         528.333333
# 14  Albania      ALB 2021-01-24                 NaN         531.444444
# 15  Albania      ALB 2021-01-25                 NaN         525.592593
# 16  Albania      ALB 2021-01-26                 NaN         528.456790
# 17  Albania      ALB 2021-01-27                 NaN         528.497942
# 18  Albania      ALB 2021-01-28                 NaN         527.515775
# 19  Albania      ALB 2021-01-29                 NaN         528.156836
# 20  Albania      ALB 2021-01-30                 NaN         528.056851
# 21  Albania      ALB 2021-01-31                 NaN         527.909821
# 22  Albania      ALB 2021-02-01                 NaN         528.041169
# 23  Albania      ALB 2021-02-02               550.0         549.000000
# 24  Albania      ALB 2021-02-03                 NaN         534.983663
# 25  Albania      ALB 2021-02-04                 NaN         537.341611
# 26  Albania      ALB 2021-02-05                 NaN         540.441758
# 27  Albania      ALB 2021-02-06                 NaN         537.589011
# 28  Albania      ALB 2021-02-07                 NaN         538.457460
# 29  Albania      ALB 2021-02-08                 NaN         538.829410
#
#     people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                64.0
# 2                       NaN                     NaN                64.0
# 3                       NaN                    60.0                63.0
# 4                       NaN                    78.0                66.0
# 5                       NaN                    42.0                62.0
# 6                       NaN                    61.0                62.0
# 7                       NaN                    36.0                58.0
# 8                       NaN                    42.0                55.0
# 9                       NaN                    36.0                51.0
# 10                      NaN                    36.0                47.0
# 11                      NaN                    30.0                40.0
# 12                      NaN                     NaN                34.0
# 13                      NaN                     NaN                26.0
# 14                      NaN                     NaN                21.0
# 15                      NaN                     NaN                15.0
# 16                      NaN                     NaN                 9.0
# 17                      NaN                     NaN                 4.0
# 18                      NaN                     NaN                 NaN
# 19                      NaN                     NaN                 NaN
# 20                      NaN                     NaN                 NaN
# 21                      NaN                     NaN                 NaN
# 22                      NaN                     NaN                 NaN
# 23                      1.0                     NaN                 NaN
# 24                      NaN                     NaN                12.0
# 25                      NaN                     NaN                24.0
# 26                      NaN                     NaN                35.0
# 27                      NaN                     NaN                47.0
# 28                      NaN                     NaN                59.0
# 29                      NaN                     NaN                71.0
#
#     total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.00                           0.00
# 1                              NaN                            NaN
# 2                             0.00                           0.00
# 3                             0.01                           0.01
# 4                             0.01                           0.01
# 5                             0.01                           0.01
# 6                             0.01                           0.01
# 7                             0.01                           0.01
# 8                             0.02                           0.02
# 9                             0.02                           0.02
# 10                            0.02                           0.02
# 11                            0.02                           0.02
# 12                             NaN                            NaN
# 13                             NaN                            NaN
# 14                             NaN                            NaN
# 15                             NaN                            NaN
# 16                             NaN                            NaN
# 17                             NaN                            NaN
# 18                             NaN                            NaN
# 19                             NaN                            NaN
# 20                             NaN                            NaN
# 21                             NaN                            NaN
# 22                             NaN                            NaN
# 23                            0.02                           0.02
# 24                             NaN                            NaN
# 25                             NaN                            NaN
# 26                             NaN                            NaN
# 27                             NaN                            NaN
# 28                             NaN                            NaN
# 29                             NaN                            NaN
#
#     people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                   NaN                             NaN
# 1                                   NaN                            22.0
# 2                                   NaN                            22.0
# 3                                   NaN                            22.0
# 4                                   NaN                            23.0
# 5                                   NaN                            22.0
# 6                                   NaN                            22.0
# 7                                   NaN                            20.0
# 8                                   NaN                            19.0
# 9                                   NaN                            18.0
# 10                                  NaN                            16.0
# 11                                  NaN                            14.0
# 12                                  NaN                            12.0
# 13                                  NaN                             9.0
# 14                                  NaN                             7.0
# 15                                  NaN                             5.0
# 16                                  NaN                             3.0
# 17                                  NaN                             1.0
# 18                                  NaN                             NaN
# 19                                  NaN                             NaN
# 20                                  NaN                             NaN
# 21                                  NaN                             NaN
# 22                                  NaN                             NaN
# 23                                  0.0                             NaN
# 24                                  NaN                             4.0
# 25                                  NaN                             8.0
# 26                                  NaN                            12.0
# 27                                  NaN                            16.0
# 28                                  NaN                            21.0
# 29                                  NaN                            25.0
#
#            vaccines         source_name  \
# 0   Pfizer/BioNTech  Ministry of Health
# 1   Pfizer/BioNTech  Ministry of Health
# 2   Pfizer/BioNTech  Ministry of Health
# 3   Pfizer/BioNTech  Ministry of Health
# 4   Pfizer/BioNTech  Ministry of Health
# 5   Pfizer/BioNTech  Ministry of Health
# 6   Pfizer/BioNTech  Ministry of Health
# 7   Pfizer/BioNTech  Ministry of Health
# 8   Pfizer/BioNTech  Ministry of Health
# 9   Pfizer/BioNTech  Ministry of Health
# 10  Pfizer/BioNTech  Ministry of Health
# 11  Pfizer/BioNTech  Ministry of Health
# 12  Pfizer/BioNTech  Ministry of Health
# 13  Pfizer/BioNTech  Ministry of Health
# 14  Pfizer/BioNTech  Ministry of Health
# 15  Pfizer/BioNTech  Ministry of Health
# 16  Pfizer/BioNTech  Ministry of Health
# 17  Pfizer/BioNTech  Ministry of Health
# 18  Pfizer/BioNTech  Ministry of Health
# 19  Pfizer/BioNTech  Ministry of Health
# 20  Pfizer/BioNTech  Ministry of Health
# 21  Pfizer/BioNTech  Ministry of Health
# 22  Pfizer/BioNTech  Ministry of Health
# 23  Pfizer/BioNTech  Ministry of Health
# 24  Pfizer/BioNTech  Ministry of Health
# 25  Pfizer/BioNTech  Ministry of Health
# 26  Pfizer/BioNTech  Ministry of Health
# 27  Pfizer/BioNTech  Ministry of Health
# 28  Pfizer/BioNTech  Ministry of Health
# 29  Pfizer/BioNTech  Ministry of Health
#
#                                        source_website
# 0   https://shendetesia.gov.al/vaksinimi-anticovid...
# 1   https://shendetesia.gov.al/vaksinimi-anticovid...
# 2   https://shendetesia.gov.al/vaksinimi-anticovid...
# 3   https://shendetesia.gov.al/vaksinimi-anticovid...
# 4   https://shendetesia.gov.al/vaksinimi-anticovid...
# 5   https://shendetesia.gov.al/vaksinimi-anticovid...
# 6   https://shendetesia.gov.al/vaksinimi-anticovid...
# 7   https://shendetesia.gov.al/vaksinimi-anticovid...
# 8   https://shendetesia.gov.al/vaksinimi-anticovid...
# 9   https://shendetesia.gov.al/vaksinimi-anticovid...
# 10  https://shendetesia.gov.al/vaksinimi-anticovid...
# 11  https://shendetesia.gov.al/vaksinimi-anticovid...
# 12  https://shendetesia.gov.al/vaksinimi-anticovid...
# 13  https://shendetesia.gov.al/vaksinimi-anticovid...
# 14  https://shendetesia.gov.al/vaksinimi-anticovid...
# 15  https://shendetesia.gov.al/vaksinimi-anticovid...
# 16  https://shendetesia.gov.al/vaksinimi-anticovid...
# 17  https://shendetesia.gov.al/vaksinimi-anticovid...
# 18  https://shendetesia.gov.al/vaksinimi-anticovid...
# 19  https://shendetesia.gov.al/vaksinimi-anticovid...
# 20  https://shendetesia.gov.al/vaksinimi-anticovid...
# 21  https://shendetesia.gov.al/vaksinimi-anticovid...
# 22  https://shendetesia.gov.al/vaksinimi-anticovid...
# 23  https://shendetesia.gov.al/vaksinimi-anticovid...
# 24  https://shendetesia.gov.al/vaksinimi-anticovid...
# 25  https://shendetesia.gov.al/vaksinimi-anticovid...
# 26  https://shendetesia.gov.al/vaksinimi-anticovid...
# 27  https://shendetesia.gov.al/vaksinimi-anticovid...
# 28  https://shendetesia.gov.al/vaksinimi-anticovid...
# 29  https://shendetesia.gov.al/vaksinimi-anticovid...

# %%
# Calcular la media de los tres valores anteriores y rellenar NaN con esa media
# df['people_vaccinated'] = df['people_vaccinated'].fillna(df['people_vaccinated'].rolling(4, min_periods=0).mean()) # Ventana de 4
# min_periods =  number of observations in window required to have a value
# df.head(30)

# %% [markdown]
# Comprobamos que se hayan modificado los valores NaN correctamente

# %%
if df['people_vaccinated'].isna().any():
    print("Hay valores NaN en la columna.")
else:
    print("No hay valores NaN en la columna.")
# Out:
# No hay valores NaN en la columna.

# %% [markdown]
# # 2.
# De aquellos 5 países que han vacunado más días en total compara su evolución en el tiempo
# (no importa que en algunas fechas no coincidan). ¿Qué diagrama has usado? ¿Porqué? Teniendo en
# cuenta que el mejor plan de vacunación es el que se mantiene más constante ¿Cuál es el país que mejor
# está llevando a cabo la vacunación? Haz una interpretación de dicho plan de vacunación.

# %%
# Agrupar por nombre y contar las entradas para cada uno
conteo = df.groupby('country').size()
conteo = conteo.sort_values(ascending=False)

# %% [markdown]
# Vemos los países con más entries, ya que cada entry es un día de vacunación en un país.

# %%
conteo[:5]
# Out:
# country
# Wales               64
# England             64
# Scotland            64
# Northern Ireland    64
# United Kingdom      64
# dtype: int64

# %% [markdown]
# Graficamos la evolución en el tiempo de ellos.

# %%
wales = df[df['country'] == 'Wales']
wales
# Out:
#      country iso_code       date  total_vaccinations  people_vaccinated  \
# 3144   Wales      NaN 2020-12-13              8207.0       8.207000e+03
# 3145   Wales      NaN 2020-12-14                 NaN       2.511887e+07
# 3146   Wales      NaN 2020-12-15                 NaN       2.113978e+07
# 3147   Wales      NaN 2020-12-16                 NaN       1.542228e+07
# 3148   Wales      NaN 2020-12-17                 NaN       2.056031e+07
# ...      ...      ...        ...                 ...                ...
# 3203   Wales      NaN 2021-02-10            687892.0       6.840970e+05
# 3204   Wales      NaN 2021-02-11            719954.0       7.159440e+05
# 3205   Wales      NaN 2021-02-12            753669.0       7.494450e+05
# 3206   Wales      NaN 2021-02-13            776224.0       7.716510e+05
# 3207   Wales      NaN 2021-02-14            790211.0       7.848090e+05
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 3144                      NaN                     NaN                 NaN
# 3145                      NaN                     NaN              2223.0
# 3146                      NaN                     NaN              2223.0
# 3147                      NaN                     NaN              2223.0
# 3148                      NaN                     NaN              2223.0
# ...                       ...                     ...                 ...
# 3203                   3795.0                 28786.0             28015.0
# 3204                   4010.0                 32062.0             27897.0
# 3205                   4224.0                 33715.0             27743.0
# 3206                   4573.0                 22555.0             26285.0
# 3207                   5402.0                 13987.0             26206.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 3144                            0.26                           0.26
# 3145                             NaN                            NaN
# 3146                             NaN                            NaN
# 3147                             NaN                            NaN
# 3148                             NaN                            NaN
# ...                              ...                            ...
# 3203                           21.82                          21.70
# 3204                           22.83                          22.71
# 3205                           23.90                          23.77
# 3206                           24.62                          24.47
# 3207                           25.06                          24.89
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 3144                                  NaN                             NaN
# 3145                                  NaN                           705.0
# 3146                                  NaN                           705.0
# 3147                                  NaN                           705.0
# 3148                                  NaN                           705.0
# ...                                   ...                             ...
# 3203                                 0.12                          8886.0
# 3204                                 0.13                          8848.0
# 3205                                 0.13                          8799.0
# 3206                                 0.15                          8337.0
# 3207                                 0.17                          8312.0
#
#                                  vaccines                       source_name  \
# 3144  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 3145  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 3146  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 3147  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 3148  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# ...                                   ...                               ...
# 3203  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 3204  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 3205  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 3206  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 3207  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
#
#                                          source_website
# 3144  https://coronavirus.data.gov.uk/details/health...
# 3145  https://coronavirus.data.gov.uk/details/health...
# 3146  https://coronavirus.data.gov.uk/details/health...
# 3147  https://coronavirus.data.gov.uk/details/health...
# 3148  https://coronavirus.data.gov.uk/details/health...
# ...                                                 ...
# 3203  https://coronavirus.data.gov.uk/details/health...
# 3204  https://coronavirus.data.gov.uk/details/health...
# 3205  https://coronavirus.data.gov.uk/details/health...
# 3206  https://coronavirus.data.gov.uk/details/health...
# 3207  https://coronavirus.data.gov.uk/details/health...
#
# [64 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
# Crear el gráfico de líneas
plt.plot(wales['date'], wales['people_vaccinated'], marker='o', linestyle='-')

# Configurar el título y etiquetas de los ejes
plt.title('Evolución de las vacunaciones')
plt.xlabel('Fecha')
plt.ylabel('Número de vacunaciones')

# Rotar las etiquetas del eje x para mejorar la legibilidad
plt.xticks(rotation=45)

# Mostrar el gráfico
plt.grid(True)
plt.tight_layout()
plt.show()
